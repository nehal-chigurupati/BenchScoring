# %%
import numpy as np
import pandas as pd
from nba_api.stats.endpoints import leaguegamelog, playbyplayv3, gamerotation, teamestimatedmetrics, teamgamelog
from nba_api.stats.static import teams
from sqlalchemy import create_engine
from scipy import stats
import time

# %%
def get_playoff_teams(season):
    # Get all teams
    nba_teams = teams.get_teams()

    # Get the standings for the specified season
    standings = leaguestandings.LeagueStandings(season=season)
    standings_data = standings.get_data_frames()[0]

    # Extract playoff teams
    playoff_teams = standings_data[standings_data["ClinchedPlayoffBirth"] == 1]["TeamID"].tolist()

    return playoff_teams

# %%
def get_teams_playoff_matchup(matchup_str):
    return matchup_str[0:3] + "," + matchup_str[-3:]

# %%
def get_series_data(team_playoff_df):
    matchup_strings = []
    for index, row in team_playoff_df.iterrows():
        matchup_strings.append(get_teams_playoff_matchup(row["MATCHUP"]))
        
    
    tot_pts_series = []
    tot_bench_pts_series = []
    w_or_l = []
    for matchup in matchup_strings:
        num_wins = 0
        tot_pts = 0
        tot_bench_pts = 0
        
        for index, row in team_playoff_df.iterrows():
            if get_teams_playoff_matchup(row["MATCHUP"]) == matchup:
                if row["WL"] == "W":
                    num_wins += 1
                tot_pts += row["PTS"]
                
                tot_bench_pts = get_bench_points(row["Game_ID"])
        if num_wins >= 4:
            w_or_l.append(1)
        else:
            w_or_l.append(0)
        
        tot_pts_series.append(tot_pts)
        tot_bench_pts_series.append(tot_bench_pts)
    
    out_dict = {
        "TOTAL_PTS": tot_pts_series,
        "TOTAL_BENCH_PTS": tot_bench_pts_series,
        "WL": w_or_l
    }
    
    return pd.DataFrame(out_dict)

# %%
def generate_nba_seasons(start_year, end_year):
    seasons = []
    for year in range(start_year, end_year):
        next_year = str(year + 1)[-2:]  # Get last two digits of the next year
        season = f"{year}-{next_year}"
        seasons.append(season)
    return seasons

# %%
def get_bench_points(game_id):
    rotation_data = gamerotation.GameRotation(game_id=game_id).get_data_frames()
    #Away team
    away_rotation_data = rotation_data[0]
    away_team_id = np.unique(rotation_data[0]["TEAM_ID"]).tolist()[0]
    
    #Home team
    home_rotation_data = rotation_data[1]
    home_team_id = np.unique(rotation_data[1]["TEAM_ID"]).tolist()[0]
    
    
    away_bench_points = 0
    for index, row in away_rotation_data.iterrows():
        if 0.0 not in away_rotation_data[away_rotation_data["PERSON_ID"] == row["PERSON_ID"]]["IN_TIME_REAL"].tolist():
            away_bench_points += row["PLAYER_PTS"]

    home_bench_points = 0
    for index, row in home_rotation_data.iterrows():
        if 0.0 not in home_rotation_data[home_rotation_data["PERSON_ID"] == row["PERSON_ID"]]["IN_TIME_REAL"].tolist():
            home_bench_points += row["PLAYER_PTS"]

    return away_bench_points, away_team_id, home_bench_points, home_team_id

# %%
engine = create_engine("sqlite:///Data/pbp_database.db")

# %%
seasons = generate_nba_seasons(2010, 2022)
all_teams = [team["id"] for team in teams.get_teams()]

# %%
#Collect game logs (including game IDs)
counter = 1
for season in seasons:
    team_ids = []
    game_ids = []
    season_ids = []
    bench_points = []
    off_ratings = []
    season_win_pct = []
    
    print("Evaluating season " + str(counter) + "/" + str(len(seasons)))
    counter += 1
    season_game_ids = np.unique(leaguegamelog.LeagueGameLog(season=season).get_data_frames()[0]["GAME_ID"])
    team_data = teamestimatedmetrics.TeamEstimatedMetrics(season=season).get_data_frames()[0]
    team_data = team_data[["TEAM_ID", "E_OFF_RATING", "W_PCT"]]
    counter_game = 1
    for game in season_game_ids:
        print("Processing game " + str(counter_game) + "/" + str(len(season_game_ids)))
        counter_game += 1
        try:
            away_bench_pts, away_id, home_bench_pts, home_id = get_bench_points(game)

            #Get offensive rating of both teams
            off_rating_away = team_data[team_data["TEAM_ID"] == away_id]["E_OFF_RATING"].tolist()[0]
            off_rating_home = team_data[team_data["TEAM_ID"] == home_id]["E_OFF_RATING"].tolist()[0]

            #Get win percent of both teams
            w_pct_away = team_data[team_data["TEAM_ID"] == away_id]["W_PCT"].tolist()[0]
            w_pct_home = team_data[team_data["TEAM_ID"] == home_id]["W_PCT"].tolist()[0]

            #Add away team data
            team_ids.append(away_id)
            game_ids.append(game)
            season_ids.append(season)
            bench_points.append(away_bench_pts)
            off_ratings.append(off_rating_away)
            season_win_pct.append(w_pct_away)

            #Add home team data
            team_ids.append(home_id)
            game_ids.append(game)
            season_ids.append(season)
            bench_points.append(home_bench_pts)
            off_ratings.append(off_rating_home)
            season_win_pct.append(w_pct_home)
        except:
            continue
        
    out = {
        'TEAM_ID': team_ids,
        "GAME_ID": game_ids,
        "SEASON": season_ids,
        "BENCH_PTS": bench_points,
        "OFF_RTG": off_ratings,
        "SEASON_W_PCT": season_win_pct
    }

    out_df = pd.DataFrame(out)
    out_df.to_csv("Data/Raw/BENCH_POINTS_REG_SEASON_" + season + ".csv")
# Out:
# Evaluating season 1/2
# Processing game 1/1230
# Processing game 2/1230
# Processing game 3/1230
# Processing game 4/1230
# Processing game 5/1230
# Processing game 6/1230
# Processing game 7/1230
# Processing game 8/1230
# Processing game 9/1230
# Processing game 10/1230
# Processing game 11/1230
# Processing game 12/1230
# Processing game 13/1230
# Processing game 14/1230
# Processing game 15/1230
# Processing game 16/1230
# Processing game 17/1230
# Processing game 18/1230
# Processing game 19/1230
# Processing game 20/1230
# Processing game 21/1230
# Processing game 22/1230
# Processing game 23/1230
# Processing game 24/1230
# Processing game 25/1230
# Processing game 26/1230
# Processing game 27/1230
# Processing game 28/1230
# Processing game 29/1230
# Processing game 30/1230
# Processing game 31/1230
# Processing game 32/1230
# Processing game 33/1230
# Processing game 34/1230
# Processing game 35/1230
# Processing game 36/1230
# Processing game 37/1230
# Processing game 38/1230
# Processing game 39/1230
# Processing game 40/1230
# Processing game 41/1230
# Processing game 42/1230
# Processing game 43/1230
# Processing game 44/1230
# Processing game 45/1230
# Processing game 46/1230
# Processing game 47/1230
# Processing game 48/1230
# Processing game 49/1230
# Processing game 50/1230
# Processing game 51/1230
# Processing game 52/1230
# Processing game 53/1230
# Processing game 54/1230
# Processing game 55/1230
# Processing game 56/1230
# Processing game 57/1230
# Processing game 58/1230
# Processing game 59/1230
# Processing game 60/1230
# Processing game 61/1230
# Processing game 62/1230
# Processing game 63/1230
# Processing game 485/1230
# Processing game 486/1230
# Processing game 487/1230
# Processing game 488/1230
# Processing game 489/1230
# Processing game 490/1230
# Processing game 491/1230
# Processing game 492/1230
# Processing game 493/1230
# Processing game 494/1230
# Processing game 495/1230
# Processing game 496/1230
# Processing game 497/1230
# Processing game 498/1230
# Processing game 499/1230
# Processing game 500/1230
# Processing game 501/1230
# Processing game 502/1230
# Processing game 503/1230
# Processing game 504/1230
# Processing game 505/1230
# Processing game 506/1230
# Processing game 507/1230
# Processing game 508/1230
# Processing game 509/1230
# Processing game 510/1230
# Processing game 511/1230
# Processing game 512/1230
# Processing game 513/1230
# Processing game 514/1230
# Processing game 515/1230
# Processing game 516/1230
# Processing game 517/1230
# Processing game 518/1230
# Processing game 519/1230
# Processing game 520/1230
# Processing game 521/1230
# Processing game 522/1230
# Processing game 523/1230
# Processing game 524/1230
# Processing game 525/1230
# Processing game 526/1230
# Processing game 527/1230
# Processing game 528/1230
# Processing game 529/1230
# Processing game 530/1230
# Processing game 531/1230
# Processing game 532/1230
# Processing game 533/1230
# Processing game 534/1230
# Processing game 535/1230
# Processing game 536/1230
# Processing game 537/1230
# Processing game 538/1230
# Processing game 539/1230
# Processing game 540/1230
# Processing game 541/1230
# Processing game 542/1230
# Processing game 543/1230
# Processing game 544/1230
# Processing game 545/1230
# Processing game 546/1230
# Processing game 547/1230
# Processing game 548/1230
# Processing game 549/1230
# Processing game 550/1230
# Processing game 551/1230
# Processing game 552/1230
# Processing game 553/1230
# Processing game 554/1230
# Processing game 555/1230
# Processing game 556/1230
# Processing game 557/1230
# Processing game 558/1230
# Processing game 559/1230
# Processing game 560/1230
# Processing game 561/1230
# Processing game 562/1230
# Processing game 563/1230
# Processing game 564/1230
# Processing game 565/1230
# Processing game 566/1230
# Processing game 567/1230
# Processing game 568/1230
# Processing game 569/1230
# Processing game 570/1230
# Processing game 571/1230
# Processing game 572/1230
# Processing game 573/1230
# Processing game 574/1230
# Processing game 575/1230
# Processing game 576/1230
# Processing game 577/1230
# Processing game 578/1230
# Processing game 579/1230
# Processing game 580/1230
# Processing game 581/1230
# Processing game 582/1230
# Processing game 583/1230
# Processing game 584/1230
# Processing game 585/1230
# Processing game 586/1230
# Processing game 587/1230
# Processing game 588/1230
# Processing game 589/1230
# Processing game 590/1230
# Processing game 591/1230
# Processing game 592/1230
# Processing game 593/1230
# Processing game 594/1230
# Processing game 595/1230
# Processing game 596/1230
# Processing game 597/1230
# Processing game 598/1230
# Processing game 599/1230
# Processing game 600/1230
# Processing game 601/1230
# Processing game 602/1230
# Processing game 603/1230
# Processing game 604/1230
# Processing game 605/1230
# Processing game 606/1230
# Processing game 607/1230
# Processing game 608/1230
# Processing game 609/1230
# Processing game 610/1230
# Processing game 611/1230
# Processing game 612/1230
# Processing game 613/1230
# Processing game 614/1230
# Processing game 615/1230
# Processing game 616/1230
# Processing game 617/1230
# Processing game 618/1230
# Processing game 619/1230
# Processing game 620/1230
# Processing game 621/1230
# Processing game 622/1230
# Processing game 623/1230
# Processing game 624/1230
# Processing game 625/1230
# Processing game 626/1230
# Processing game 627/1230
# Processing game 628/1230
# Processing game 629/1230
# Processing game 630/1230
# Processing game 631/1230
# Processing game 632/1230
# Processing game 633/1230
# Processing game 634/1230
# Processing game 635/1230
# Processing game 636/1230
# Processing game 637/1230
# Processing game 638/1230
# Processing game 639/1230
# Processing game 640/1230
# Processing game 641/1230
# Processing game 642/1230
# Processing game 643/1230
# Processing game 644/1230
# Processing game 645/1230
# Processing game 646/1230
# Processing game 647/1230
# Processing game 648/1230
# Processing game 649/1230
# Processing game 650/1230
# Processing game 651/1230
# Processing game 652/1230
# Processing game 653/1230
# Processing game 654/1230
# Processing game 655/1230
# Processing game 656/1230
# Processing game 657/1230
# Processing game 658/1230
# Processing game 659/1230
# Processing game 660/1230
# Processing game 661/1230
# Processing game 662/1230
# Processing game 663/1230
# Processing game 664/1230
# Processing game 665/1230
# Processing game 666/1230
# Processing game 667/1230
# Processing game 668/1230
# Processing game 669/1230
# Processing game 670/1230
# Processing game 671/1230
# Processing game 672/1230
# Processing game 673/1230
# Processing game 674/1230
# Processing game 675/1230
# Processing game 676/1230
# Processing game 677/1230
# Processing game 678/1230
# Processing game 679/1230
# Processing game 680/1230
# Processing game 681/1230
# Processing game 682/1230
# Processing game 683/1230
# Processing game 684/1230
# Processing game 685/1230
# Processing game 686/1230
# Processing game 687/1230
# Processing game 688/1230
# Processing game 689/1230
# Processing game 690/1230
# Processing game 691/1230
# Processing game 692/1230
# Processing game 693/1230
# Processing game 694/1230
# Processing game 695/1230
# Processing game 696/1230
# Processing game 697/1230
# Processing game 698/1230
# Processing game 699/1230
# Processing game 700/1230
# Processing game 701/1230
# Processing game 702/1230
# Processing game 703/1230
# Processing game 704/1230
# Processing game 705/1230
# Processing game 706/1230
# Processing game 707/1230
# Processing game 708/1230
# Processing game 709/1230
# Processing game 710/1230
# Processing game 711/1230
# Processing game 712/1230
# Processing game 713/1230
# Processing game 714/1230
# Processing game 715/1230
# Processing game 716/1230
# Processing game 717/1230
# Processing game 718/1230
# Processing game 719/1230
# Processing game 720/1230
# Processing game 721/1230
# Processing game 722/1230
# Processing game 723/1230
# Processing game 724/1230
# Processing game 725/1230
# Processing game 726/1230
# Processing game 727/1230
# Processing game 728/1230
# Processing game 729/1230
# Processing game 730/1230
# Processing game 731/1230
# Processing game 732/1230
# Processing game 733/1230
# Processing game 734/1230
# Processing game 735/1230
# Processing game 736/1230
# Processing game 737/1230
# Processing game 738/1230
# Processing game 739/1230
# Processing game 740/1230
# Processing game 741/1230
# Processing game 742/1230
# Processing game 743/1230
# Processing game 744/1230
# Processing game 745/1230
# Processing game 746/1230
# Processing game 747/1230
# Processing game 748/1230
# Processing game 749/1230
# Processing game 750/1230
# Processing game 751/1230
# Processing game 752/1230
# Processing game 753/1230
# Processing game 754/1230
# Processing game 755/1230
# Processing game 756/1230
# Processing game 757/1230
# Processing game 758/1230
# Processing game 759/1230
# Processing game 760/1230
# Processing game 761/1230
# Processing game 762/1230
# Processing game 763/1230
# Processing game 764/1230
# Processing game 765/1230
# Processing game 766/1230
# Processing game 767/1230
# Processing game 768/1230
# Processing game 769/1230
# Processing game 770/1230
# Processing game 771/1230
# Processing game 772/1230
# Processing game 773/1230
# Processing game 774/1230
# Processing game 775/1230
# Processing game 776/1230
# Processing game 777/1230
# Processing game 778/1230
# Processing game 779/1230
# Processing game 780/1230
# Processing game 781/1230
# Processing game 782/1230
# Processing game 783/1230
# Processing game 784/1230
# Processing game 785/1230
# Processing game 786/1230
# Processing game 787/1230
# Processing game 788/1230
# Processing game 789/1230
# Processing game 790/1230
# Processing game 791/1230
# Processing game 792/1230
# Processing game 793/1230
# Processing game 794/1230
# Processing game 795/1230
# Processing game 796/1230
# Processing game 797/1230
# Processing game 798/1230
# Processing game 799/1230
# Processing game 800/1230
# Processing game 801/1230
# Processing game 802/1230
# Processing game 803/1230
# Processing game 804/1230
# Processing game 805/1230
# Processing game 806/1230
# Processing game 807/1230
# Processing game 808/1230
# Processing game 809/1230
# Processing game 810/1230
# Processing game 811/1230
# Processing game 812/1230
# Processing game 813/1230
# Processing game 814/1230
# Processing game 815/1230
# Processing game 816/1230
# Processing game 817/1230
# Processing game 818/1230
# Processing game 819/1230
# Processing game 820/1230
# Processing game 821/1230
# Processing game 822/1230
# Processing game 823/1230
# Processing game 824/1230
# Processing game 825/1230
# Processing game 826/1230
# Processing game 827/1230
# Processing game 828/1230
# Processing game 829/1230
# Processing game 830/1230
# Processing game 831/1230
# Processing game 832/1230
# Processing game 833/1230
# Processing game 834/1230
# Processing game 835/1230
# Processing game 836/1230
# Processing game 837/1230
# Processing game 838/1230
# Processing game 839/1230
# Processing game 840/1230
# Processing game 841/1230
# Processing game 842/1230
# Processing game 843/1230
# Processing game 844/1230
# Processing game 845/1230
# Processing game 846/1230
# Processing game 847/1230
# Processing game 848/1230
# Processing game 849/1230
# Processing game 850/1230
# Processing game 851/1230
# Processing game 852/1230
# Processing game 853/1230
# Processing game 854/1230
# Processing game 855/1230
# Processing game 856/1230
# Processing game 857/1230
# Processing game 858/1230
# Processing game 859/1230
# Processing game 860/1230
# Processing game 861/1230
# Processing game 862/1230
# Processing game 863/1230
# Processing game 864/1230
# Processing game 865/1230
# Processing game 866/1230
# Processing game 867/1230
# Processing game 868/1230
# Processing game 869/1230
# Processing game 870/1230
# Processing game 871/1230
# Processing game 872/1230
# Processing game 873/1230
# Processing game 874/1230
# Processing game 875/1230
# Processing game 876/1230
# Processing game 877/1230
# Processing game 878/1230
# Processing game 879/1230
# Processing game 880/1230
# Processing game 881/1230
# Processing game 882/1230
# Processing game 883/1230
# Processing game 884/1230
# Processing game 885/1230
# Processing game 886/1230
# Processing game 887/1230
# Processing game 888/1230
# Processing game 889/1230
# Processing game 890/1230
# Processing game 891/1230
# Processing game 892/1230
# Processing game 893/1230
# Processing game 894/1230
# Processing game 895/1230
# Processing game 896/1230
# Processing game 897/1230
# Processing game 898/1230
# Processing game 899/1230
# Processing game 900/1230
# Processing game 901/1230
# Processing game 902/1230
# Processing game 903/1230
# Processing game 904/1230
# Processing game 905/1230
# Processing game 906/1230
# Processing game 76/1230
# Processing game 77/1230
# Processing game 78/1230
# Processing game 79/1230
# Processing game 80/1230
# Processing game 81/1230
# Processing game 82/1230
# Processing game 83/1230
# Processing game 84/1230
# Processing game 85/1230
# Processing game 86/1230
# Processing game 87/1230
# Processing game 88/1230
# Processing game 89/1230
# Processing game 90/1230
# Processing game 91/1230
# Processing game 92/1230
# Processing game 93/1230
# Processing game 94/1230
# Processing game 95/1230
# Processing game 96/1230
# Processing game 97/1230
# Processing game 98/1230
# Processing game 99/1230
# Processing game 100/1230
# Processing game 101/1230
# Processing game 102/1230
# Processing game 103/1230
# Processing game 104/1230
# Processing game 105/1230
# Processing game 106/1230
# Processing game 107/1230
# Processing game 108/1230
# Processing game 109/1230
# Processing game 110/1230
# Processing game 111/1230
# Processing game 112/1230
# Processing game 113/1230
# Processing game 114/1230
# Processing game 115/1230
# Processing game 116/1230
# Processing game 117/1230
# Processing game 118/1230
# Processing game 119/1230
# Processing game 120/1230
# Processing game 121/1230
# Processing game 122/1230
# Processing game 123/1230
# Processing game 124/1230
# Processing game 125/1230
# Processing game 126/1230
# Processing game 127/1230
# Processing game 128/1230
# Processing game 129/1230
# Processing game 130/1230
# Processing game 131/1230
# Processing game 132/1230
# Processing game 133/1230
# Processing game 134/1230
# Processing game 135/1230
# Processing game 136/1230
# Processing game 137/1230
# Processing game 138/1230
# Processing game 139/1230
# Processing game 140/1230
# Processing game 141/1230
# Processing game 142/1230
# Processing game 143/1230
# Processing game 144/1230
# Processing game 145/1230
# Processing game 146/1230
# Processing game 147/1230
# Processing game 148/1230
# Processing game 149/1230
# Processing game 150/1230
# Processing game 151/1230
# Processing game 152/1230
# Processing game 153/1230
# Processing game 154/1230
# Processing game 155/1230
# Processing game 156/1230
# Processing game 157/1230
# Processing game 158/1230
# Processing game 159/1230
# Processing game 160/1230
# Processing game 161/1230
# Processing game 162/1230
# Processing game 163/1230
# Processing game 164/1230
# Processing game 165/1230
# Processing game 166/1230
# Processing game 167/1230
# Processing game 168/1230
# Processing game 169/1230
# Processing game 170/1230
# Processing game 171/1230
# Processing game 172/1230
# Processing game 173/1230
# Processing game 174/1230
# Processing game 175/1230
# Processing game 176/1230
# Processing game 177/1230
# Processing game 178/1230
# Processing game 179/1230
# Processing game 180/1230
# Processing game 181/1230
# Processing game 182/1230
# Processing game 183/1230
# Processing game 184/1230
# Processing game 185/1230
# Processing game 186/1230
# Processing game 187/1230
# Processing game 188/1230
# Processing game 189/1230
# Processing game 190/1230
# Processing game 191/1230
# Processing game 192/1230
# Processing game 193/1230
# Processing game 194/1230
# Processing game 195/1230
# Processing game 196/1230
# Processing game 197/1230
# Processing game 198/1230
# Processing game 199/1230
# Processing game 200/1230
# Processing game 201/1230
# Processing game 202/1230
# Processing game 203/1230
# Processing game 204/1230
# Processing game 205/1230
# Processing game 206/1230
# Processing game 207/1230
# Processing game 208/1230
# Processing game 209/1230
# Processing game 210/1230
# Processing game 211/1230
# Processing game 212/1230
# Processing game 213/1230
# Processing game 214/1230
# Processing game 215/1230
# Processing game 216/1230
# Processing game 217/1230
# Processing game 218/1230
# Processing game 219/1230
# Processing game 220/1230
# Processing game 221/1230
# Processing game 222/1230
# Processing game 223/1230
# Processing game 224/1230
# Processing game 225/1230
# Processing game 226/1230
# Processing game 227/1230
# Processing game 228/1230
# Processing game 229/1230
# Processing game 230/1230
# Processing game 231/1230
# Processing game 232/1230
# Processing game 233/1230
# Processing game 234/1230
# Processing game 235/1230
# Processing game 236/1230
# Processing game 237/1230
# Processing game 238/1230
# Processing game 239/1230
# Processing game 240/1230
# Processing game 241/1230
# Processing game 242/1230
# Processing game 243/1230
# Processing game 244/1230
# Processing game 245/1230
# Processing game 246/1230
# Processing game 247/1230
# Processing game 248/1230
# Processing game 249/1230
# Processing game 250/1230
# Processing game 251/1230
# Processing game 252/1230
# Processing game 253/1230
# Processing game 254/1230
# Processing game 255/1230
# Processing game 256/1230
# Processing game 257/1230
# Processing game 258/1230
# Processing game 259/1230
# Processing game 260/1230
# Processing game 261/1230
# Processing game 262/1230
# Processing game 263/1230
# Processing game 264/1230
# Processing game 265/1230
# Processing game 266/1230
# Processing game 267/1230
# Processing game 268/1230
# Processing game 269/1230
# Processing game 270/1230
# Processing game 271/1230
# Processing game 272/1230
# Processing game 273/1230
# Processing game 274/1230
# Processing game 275/1230
# Processing game 276/1230
# Processing game 277/1230
# Processing game 278/1230
# Processing game 279/1230
# Processing game 280/1230
# Processing game 281/1230
# Processing game 282/1230
# Processing game 283/1230
# Processing game 284/1230
# Processing game 285/1230
# Processing game 286/1230
# Processing game 287/1230
# Processing game 288/1230
# Processing game 289/1230
# Processing game 290/1230
# Processing game 291/1230
# Processing game 292/1230
# Processing game 293/1230
# Processing game 294/1230
# Processing game 295/1230
# Processing game 296/1230
# Processing game 297/1230
# Processing game 298/1230
# Processing game 299/1230
# Processing game 300/1230
# Processing game 301/1230
# Processing game 302/1230
# Processing game 303/1230
# Processing game 304/1230
# Processing game 305/1230
# Processing game 306/1230
# Processing game 307/1230
# Processing game 308/1230
# Processing game 309/1230
# Processing game 310/1230
# Processing game 311/1230
# Processing game 312/1230
# Processing game 313/1230
# Processing game 314/1230
# Processing game 315/1230
# Processing game 316/1230
# Processing game 317/1230
# Processing game 318/1230
# Processing game 319/1230
# Processing game 320/1230
# Processing game 321/1230
# Processing game 322/1230
# Processing game 323/1230
# Processing game 324/1230
# Processing game 325/1230
# Processing game 326/1230
# Processing game 327/1230
# Processing game 328/1230
# Processing game 329/1230
# Processing game 330/1230
# Processing game 331/1230
# Processing game 332/1230
# Processing game 333/1230
# Processing game 334/1230
# Processing game 335/1230
# Processing game 336/1230
# Processing game 337/1230
# Processing game 338/1230
# Processing game 339/1230
# Processing game 340/1230
# Processing game 341/1230
# Processing game 342/1230
# Processing game 343/1230
# Processing game 344/1230
# Processing game 345/1230
# Processing game 346/1230
# Processing game 347/1230
# Processing game 348/1230
# Processing game 349/1230
# Processing game 350/1230
# Processing game 351/1230
# Processing game 352/1230
# Processing game 353/1230
# Processing game 354/1230
# Processing game 355/1230
# Processing game 356/1230
# Processing game 498/1230
# Processing game 499/1230
# Processing game 500/1230
# Processing game 501/1230
# Processing game 502/1230
# Processing game 503/1230
# Processing game 504/1230
# Processing game 505/1230
# Processing game 506/1230
# Processing game 507/1230
# Processing game 508/1230
# Processing game 509/1230
# Processing game 510/1230
# Processing game 511/1230
# Processing game 512/1230
# Processing game 513/1230
# Processing game 514/1230
# Processing game 515/1230
# Processing game 516/1230
# Processing game 517/1230
# Processing game 518/1230
# Processing game 519/1230
# Processing game 520/1230
# Processing game 521/1230
# Processing game 522/1230
# Processing game 523/1230
# Processing game 524/1230
# Processing game 525/1230
# Processing game 526/1230
# Processing game 527/1230
# Processing game 528/1230
# Processing game 529/1230
# Processing game 530/1230
# Processing game 531/1230
# Processing game 532/1230
# Processing game 533/1230
# Processing game 534/1230
# Processing game 535/1230
# Processing game 536/1230
# Processing game 537/1230
# Processing game 538/1230
# Processing game 539/1230
# Processing game 540/1230
# Processing game 541/1230
# Processing game 542/1230
# Processing game 543/1230
# Processing game 544/1230
# Processing game 545/1230
# Processing game 546/1230
# Processing game 547/1230
# Processing game 548/1230
# Processing game 549/1230
# Processing game 550/1230
# Processing game 551/1230
# Processing game 552/1230
# Processing game 553/1230
# Processing game 554/1230
# Processing game 555/1230
# Processing game 556/1230
# Processing game 557/1230
# Processing game 558/1230
# Processing game 559/1230
# Processing game 560/1230
# Processing game 561/1230
# Processing game 562/1230
# Processing game 563/1230
# Processing game 564/1230
# Processing game 565/1230
# Processing game 566/1230
# Processing game 567/1230
# Processing game 568/1230
# Processing game 569/1230
# Processing game 570/1230
# Processing game 571/1230
# Processing game 572/1230
# Processing game 573/1230
# Processing game 574/1230
# Processing game 575/1230
# Processing game 576/1230
# Processing game 577/1230
# Processing game 578/1230
# Processing game 579/1230
# Processing game 580/1230
# Processing game 581/1230
# Processing game 582/1230
# Processing game 583/1230
# Processing game 584/1230
# Processing game 585/1230
# Processing game 586/1230
# Processing game 587/1230
# Processing game 588/1230
# Processing game 589/1230
# Processing game 590/1230
# Processing game 591/1230
# Processing game 592/1230
# Processing game 593/1230
# Processing game 594/1230
# Processing game 595/1230
# Processing game 596/1230
# Processing game 597/1230
# Processing game 598/1230
# Processing game 599/1230
# Processing game 600/1230
# Processing game 601/1230
# Processing game 602/1230
# Processing game 603/1230
# Processing game 604/1230
# Processing game 605/1230
# Processing game 606/1230
# Processing game 607/1230
# Processing game 608/1230
# Processing game 609/1230
# Processing game 610/1230
# Processing game 611/1230
# Processing game 612/1230
# Processing game 613/1230
# Processing game 614/1230
# Processing game 615/1230
# Processing game 616/1230
# Processing game 617/1230
# Processing game 618/1230
# Processing game 619/1230
# Processing game 620/1230
# Processing game 621/1230
# Processing game 622/1230
# Processing game 623/1230
# Processing game 624/1230
# Processing game 625/1230
# Processing game 626/1230
# Processing game 627/1230
# Processing game 628/1230
# Processing game 629/1230
# Processing game 630/1230
# Processing game 631/1230
# Processing game 632/1230
# Processing game 633/1230
# Processing game 634/1230
# Processing game 635/1230
# Processing game 636/1230
# Processing game 637/1230
# Processing game 638/1230
# Processing game 639/1230
# Processing game 640/1230
# Processing game 641/1230
# Processing game 642/1230
# Processing game 643/1230
# Processing game 644/1230
# Processing game 645/1230
# Processing game 646/1230
# Processing game 647/1230
# Processing game 648/1230
# Processing game 649/1230
# Processing game 650/1230
# Processing game 651/1230
# Processing game 652/1230
# Processing game 653/1230
# Processing game 654/1230
# Processing game 655/1230
# Processing game 656/1230
# Processing game 657/1230
# Processing game 658/1230
# Processing game 659/1230
# Processing game 660/1230
# Processing game 661/1230
# Processing game 662/1230
# Processing game 663/1230
# Processing game 664/1230
# Processing game 665/1230
# Processing game 666/1230
# Processing game 667/1230
# Processing game 668/1230
# Processing game 669/1230
# Processing game 670/1230
# Processing game 671/1230
# Processing game 672/1230
# Processing game 673/1230
# Processing game 674/1230
# Processing game 675/1230
# Processing game 676/1230
# Processing game 677/1230
# Processing game 678/1230
# Processing game 679/1230
# Processing game 680/1230
# Processing game 681/1230
# Processing game 682/1230
# Processing game 683/1230
# Processing game 684/1230
# Processing game 685/1230
# Processing game 686/1230
# Processing game 687/1230
# Processing game 688/1230
# Processing game 689/1230
# Processing game 690/1230
# Processing game 691/1230
# Processing game 692/1230
# Processing game 693/1230
# Processing game 694/1230
# Processing game 695/1230
# Processing game 696/1230
# Processing game 697/1230
# Processing game 698/1230
# Processing game 699/1230
# Processing game 700/1230
# Processing game 701/1230
# Processing game 702/1230
# Processing game 703/1230
# Processing game 704/1230
# Processing game 705/1230
# Processing game 706/1230
# Processing game 707/1230
# Processing game 708/1230
# Processing game 709/1230
# Processing game 710/1230
# Processing game 711/1230
# Processing game 712/1230
# Processing game 713/1230
# Processing game 714/1230
# Processing game 715/1230
# Processing game 716/1230
# Processing game 717/1230
# Processing game 718/1230
# Processing game 719/1230
# Processing game 720/1230
# Processing game 721/1230
# Processing game 722/1230
# Processing game 723/1230
# Processing game 724/1230
# Processing game 725/1230
# Processing game 726/1230
# Processing game 727/1230
# Processing game 728/1230
# Processing game 729/1230
# Processing game 730/1230
# Processing game 731/1230
# Processing game 732/1230
# Processing game 733/1230
# Processing game 734/1230
# Processing game 735/1230
# Processing game 736/1230
# Processing game 737/1230
# Processing game 738/1230
# Processing game 739/1230
# Processing game 740/1230
# Processing game 741/1230
# Processing game 742/1230
# Processing game 743/1230
# Processing game 744/1230
# Processing game 745/1230
# Processing game 746/1230
# Processing game 747/1230
# Processing game 748/1230
# Processing game 749/1230
# Processing game 750/1230
# Processing game 751/1230
# Processing game 752/1230
# Processing game 753/1230
# Processing game 754/1230
# Processing game 755/1230
# Processing game 756/1230
# Processing game 757/1230
# Processing game 758/1230
# Processing game 759/1230
# Processing game 760/1230
# Processing game 761/1230
# Processing game 762/1230
# Processing game 763/1230
# Processing game 764/1230
# Processing game 765/1230
# Processing game 766/1230
# Processing game 767/1230
# Processing game 768/1230
# Processing game 769/1230
# Processing game 770/1230
# Processing game 771/1230
# Processing game 772/1230
# Processing game 773/1230
# Processing game 774/1230
# Processing game 775/1230
# Processing game 776/1230
# Processing game 777/1230
# Processing game 778/1230
# Processing game 779/1230
# Processing game 780/1230
# Processing game 781/1230
# Processing game 782/1230
# Processing game 783/1230
# Processing game 784/1230
# Processing game 785/1230
# Processing game 786/1230
# Processing game 787/1230
# Processing game 788/1230
# Processing game 789/1230
# Processing game 790/1230
# Processing game 791/1230
# Processing game 792/1230
# Processing game 793/1230
# Processing game 794/1230
# Processing game 795/1230
# Processing game 796/1230
# Processing game 797/1230
# Processing game 798/1230
# Processing game 799/1230
# Processing game 800/1230
# Processing game 801/1230
# Processing game 802/1230
# Processing game 803/1230
# Processing game 804/1230
# Processing game 805/1230
# Processing game 806/1230
# Processing game 807/1230
# Processing game 808/1230
# Processing game 809/1230
# Processing game 810/1230
# Processing game 811/1230
# Processing game 812/1230
# Processing game 813/1230
# Processing game 814/1230
# Processing game 815/1230
# Processing game 816/1230
# Processing game 817/1230
# Processing game 818/1230
# Processing game 819/1230
# Processing game 820/1230
# Processing game 821/1230
# Processing game 822/1230
# Processing game 823/1230
# Processing game 824/1230
# Processing game 825/1230
# Processing game 826/1230
# Processing game 827/1230
# Processing game 828/1230
# Processing game 829/1230
# Processing game 830/1230
# Processing game 831/1230
# Processing game 832/1230
# Processing game 833/1230
# Processing game 834/1230
# Processing game 835/1230
# Processing game 836/1230
# Processing game 837/1230
# Processing game 838/1230
# Processing game 839/1230
# Processing game 840/1230
# Processing game 841/1230
# Processing game 842/1230
# Processing game 843/1230
# Processing game 844/1230
# Processing game 845/1230
# Processing game 846/1230
# Processing game 847/1230
# Processing game 848/1230
# Processing game 849/1230
# Processing game 850/1230
# Processing game 851/1230
# Processing game 852/1230
# Processing game 853/1230
# Processing game 854/1230
# Processing game 855/1230
# Processing game 856/1230
# Processing game 857/1230
# Processing game 858/1230
# Processing game 859/1230
# Processing game 860/1230
# Processing game 861/1230
# Processing game 862/1230
# Processing game 863/1230
# Processing game 864/1230
# Processing game 865/1230
# Processing game 866/1230
# Processing game 867/1230
# Processing game 868/1230
# Processing game 869/1230
# Processing game 870/1230
# Processing game 871/1230
# Processing game 872/1230
# Processing game 873/1230
# Processing game 874/1230
# Processing game 875/1230
# Processing game 876/1230
# Processing game 877/1230
# Processing game 878/1230
# Processing game 879/1230
# Processing game 880/1230
# Processing game 881/1230
# Processing game 882/1230
# Processing game 883/1230
# Processing game 884/1230
# Processing game 885/1230
# Processing game 886/1230
# Processing game 887/1230
# Processing game 888/1230
# Processing game 889/1230
# Processing game 890/1230
# Processing game 891/1230
# Processing game 892/1230
# Processing game 893/1230
# Processing game 894/1230
# Processing game 895/1230
# Processing game 896/1230
# Processing game 897/1230
# Processing game 898/1230
# Processing game 899/1230
# Processing game 900/1230
# Processing game 901/1230
# Processing game 902/1230
# Processing game 903/1230
# Processing game 904/1230
# Processing game 905/1230
# Processing game 906/1230
# Processing game 907/1230
# Processing game 908/1230
# Processing game 909/1230
# Processing game 910/1230
# Processing game 911/1230
# Processing game 912/1230
# Processing game 913/1230
# Processing game 914/1230
# Processing game 915/1230
# Processing game 916/1230
# Processing game 917/1230
# Processing game 918/1230
# Processing game 919/1230
# Processing game 920/1230
# Processing game 921/1230
# Processing game 922/1230
# Processing game 923/1230
# Processing game 924/1230
# Processing game 925/1230
# Processing game 926/1230
# Processing game 927/1230
# Processing game 928/1230
# Processing game 929/1230
# Processing game 930/1230
# Processing game 931/1230
# Processing game 932/1230
# Processing game 933/1230
# Processing game 934/1230
# Processing game 935/1230
# Processing game 936/1230
# Processing game 937/1230
# Processing game 938/1230
# Processing game 939/1230
# Processing game 940/1230
# Processing game 941/1230
# Processing game 942/1230
# Processing game 943/1230
# Processing game 944/1230
# Processing game 945/1230
# Processing game 946/1230
# Processing game 947/1230
# Processing game 948/1230
# Processing game 949/1230
# Processing game 950/1230
# Processing game 951/1230
# Processing game 952/1230
# Processing game 953/1230
# Processing game 954/1230
# Processing game 955/1230
# Processing game 956/1230
# Processing game 957/1230
# Processing game 958/1230
# Processing game 959/1230
# Processing game 960/1230
# Processing game 961/1230
# Processing game 962/1230
# Processing game 963/1230
# Processing game 964/1230
# Processing game 965/1230
# Processing game 966/1230
# Processing game 967/1230
# Processing game 968/1230
# Processing game 969/1230
# Processing game 970/1230
# Processing game 971/1230
# Processing game 972/1230
# Processing game 973/1230
# Processing game 974/1230
# Processing game 975/1230
# Processing game 976/1230
# Processing game 977/1230
# Processing game 978/1230
# Processing game 979/1230
# Processing game 980/1230
# Processing game 981/1230
# Processing game 982/1230
# Processing game 983/1230
# Processing game 984/1230
# Processing game 985/1230
# Processing game 986/1230
# Processing game 987/1230
# Processing game 988/1230
# Processing game 989/1230
# Processing game 990/1230
# Processing game 991/1230
# Processing game 992/1230
# Processing game 993/1230
# Processing game 994/1230
# Processing game 995/1230
# Processing game 996/1230
# Processing game 997/1230
# Processing game 998/1230
# Processing game 999/1230
# Processing game 1000/1230
# Processing game 1001/1230
# Processing game 1002/1230
# Processing game 1003/1230
# Processing game 1004/1230
# Processing game 1005/1230
# Processing game 1006/1230
# Processing game 1007/1230
# Processing game 1008/1230
# Processing game 1009/1230
# Processing game 1010/1230
# Processing game 1011/1230
# Processing game 1012/1230
# Processing game 1013/1230
# Processing game 1014/1230
# Processing game 1015/1230
# Processing game 1016/1230
# Processing game 1017/1230
# Processing game 1018/1230
# Processing game 1019/1230
# Processing game 1020/1230
# Processing game 1021/1230
# Processing game 1022/1230
# Processing game 1023/1230
# Processing game 1024/1230
# Processing game 1025/1230
# Processing game 1026/1230
# Processing game 1027/1230
# Processing game 1028/1230
# Processing game 1029/1230
# Processing game 1030/1230
# Processing game 1031/1230
# Processing game 1032/1230
# Processing game 1033/1230
# Processing game 1034/1230
# Processing game 1035/1230
# Processing game 1036/1230
# Processing game 1037/1230
# Processing game 1038/1230
# Processing game 1039/1230
# Processing game 1040/1230
# Processing game 1041/1230
# Processing game 1042/1230
# Processing game 1043/1230
# Processing game 1044/1230
# Processing game 1045/1230
# Processing game 1046/1230
# Processing game 1047/1230
# Processing game 1048/1230
# Processing game 1049/1230
# Processing game 1050/1230
# Processing game 1051/1230
# Processing game 1052/1230
# Processing game 1053/1230
# Processing game 1054/1230
# Processing game 1184/1230
# Processing game 1185/1230
# Processing game 1186/1230
# Processing game 1187/1230
# Processing game 1188/1230
# Processing game 1189/1230
# Processing game 1190/1230
# Processing game 1191/1230
# Processing game 1192/1230
# Processing game 1193/1230
# Processing game 1194/1230
# Processing game 1195/1230
# Processing game 1196/1230
# Processing game 1197/1230
# Processing game 1198/1230
# Processing game 1199/1230
# Processing game 1200/1230
# Processing game 1201/1230
# Processing game 1202/1230
# Processing game 1203/1230
# Processing game 1204/1230
# Processing game 1205/1230
# Processing game 1206/1230
# Processing game 1207/1230
# Processing game 1208/1230
# Processing game 1209/1230
# Processing game 1210/1230
# Processing game 1211/1230
# Processing game 1212/1230
# Processing game 1213/1230
# Processing game 1214/1230
# Processing game 1215/1230
# Processing game 1216/1230
# Processing game 1217/1230
# Processing game 1218/1230
# Processing game 1219/1230
# Processing game 1220/1230
# Processing game 1221/1230
# Processing game 1222/1230
# Processing game 1223/1230
# Processing game 1224/1230
# Processing game 1225/1230
# Processing game 1226/1230
# Processing game 1227/1230
# Processing game 1228/1230
# Processing game 1229/1230
# Processing game 1230/1230

# %%
#Collect data for team points in each game
all_data = []
counter = 1
for season in seasons:
    season_data = []
    
    print("Evaluating season " + str(counter) + "/" + str(len(seasons)))
    counter += 1
    season_data = leaguegamelog.LeagueGameLog(season=season).get_data_frames()[0][["GAME_ID", "TEAM_ID", "PTS"]]
    all_data.append(season_data)

all_data = pd.concat(all_data)
# Out:
# Evaluating season 1/12
# Evaluating season 2/12
# Evaluating season 3/12
# Evaluating season 4/12
# Evaluating season 5/12
# Evaluating season 6/12
# Evaluating season 7/12
# Evaluating season 8/12
# Evaluating season 9/12
# Evaluating season 10/12
# Evaluating season 11/12
# Evaluating season 12/12

# %%
print(all_data)
# Out:
#          GAME_ID     TEAM_ID  PTS
# 0     0021000001  1610612748   80
# 1     0021000001  1610612738   88
# 2     0021000002  1610612756   92
# 3     0021000002  1610612757  106
# 4     0021000003  1610612745  110
# ...          ...         ...  ...
# 2455  0022101220  1610612743  141
# 2456  0022101226  1610612752  105
# 2457  0022101217  1610612766  124
# 2458  0022101225  1610612740  107
# 2459  0022101229  1610612756  109
#
# [28398 rows x 3 columns]

# %%
all_data.to_csv("Data/Raw/TOTAL_GAME_POINTS_DATA.csv")

# %%
"""
Next, collect playoff series data.
"""

# %%
#Get all playoff rounds
series = []

for season in seasons:
    print(season)
    playoff_teams = get_playoff_teams(season)
    
    counter = 1
    for team in playoff_teams:
        time.sleep(1)
        print("Team " + str(counter) + "/" + str(len(playoff_teams)))
        counter += 1
        
        playoff_games = teamgamelog.TeamGameLog(season=season, season_type_all_star="Playoffs", team_id=team)
        playoff_games = playoff_games.get_data_frames()[0]
        
        team_series = get_series_data(playoff_games)
        series.append(team_series)

all_series = pd.concat(series)
# Out:
# 2010-11
# Team 1/16
# here2
# 0
# 80
# here2
# 80
# 173
# here2
# 173
# 258
# here2
# 258
# 333
# here2
# 333
# 436
# here2
# 0
# 80
# here2
# 80
# 173
# here2
# 173
# 258
# here2
# here2
# 178
# 259
# here2
# 259
# 353
# here2
# 0
# 98
# here2
# 98
# 204
# here2
# 204
# 292
# here2
# 292
# 392
# here2
# 392
# 479
# here2
# 479
# 579
# here2
# 0
# 98
# here2
# 98
# 204
# here2
# 204
# 292
# here2
# 292
# 392
# here2
# 392
# 479
# here2
# 479
# 579
# here2
# 0
# 98
# here2
# 98
# 204
# here2
# 204
# 292
# here2
# 292
# 392
# here2
# 392
# 479
# here2
# 479
# 579
# here2
# 0
# 98
# here2
# 98
# 204
# here2
# 204
# 292
# here2
# 292
# 392
# here2
# 392
# 479
# here2
# 479
# 579
# here2
# 0
# 98
# here2
# 98
# 204
# here2
# 204
# 292
# here2
# 292
# 392
# here2
# 392
# 479
# here2
# 479
# 579
# here2
# 0
# 98
# here2
# 98
# 204
# here2
# 204
# 292
# here2
# 292
# 392
# here2
# 392
# 479
# here2
# 479
# 579
# Team 4/16
# here2
# 0
# 95
# here2
# 95
# 198
# here2
# 198
# 281
# here2
# 281
# 369
# here2
# 369
# 462
# here2
# 462
# 554
# here2
# 0
# 95
# here2
# 95
# 198
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 17
#      14         playoff_games = teamgamelog.TeamGameLog(season=season, season_type_all_star="Playoffs", team_id=team)
#      15         playoff_games = playoff_games.get_data_frames()[0]
# ---> 17         team_series = get_series_data(playoff_games)
#      18         series.append(team_series)
#      20 all_series = pd.concat(series)
#
# Cell In[70], line 24, in get_series_data(team_playoff_df)
#      21         tot_pts += row["PTS"]
#      22         print(tot_pts)
# ---> 24         tot_bench_pts = get_bench_points(row["Game_ID"])
#      25 if num_wins >= 4:
#      26     w_or_l.append(1)
#
# Cell In[64], line 2, in get_bench_points(game_id)
#       1 def get_bench_points(game_id):
# ----> 2     rotation_data = gamerotation.GameRotation(game_id=game_id).get_data_frames()
#       3     #Away team
#       4     away_rotation_data = rotation_data[0]
#
# File ~/miniconda3/lib/python3.11/site-packages/nba_api/stats/endpoints/gamerotation.py:32, in GameRotation.__init__(self, game_id, league_id, proxy, headers, timeout, get_request)
#      27 self.parameters = {
#      28         'GameID': game_id,
#      29         'LeagueID': league_id
#      30 }
#      31 if get_request:
# ---> 32     self.get_request()
#
# File ~/miniconda3/lib/python3.11/site-packages/nba_api/stats/endpoints/gamerotation.py:35, in GameRotation.get_request(self)
#      34 def get_request(self):
# ---> 35     self.nba_response = NBAStatsHTTP().send_api_request(
#      36         endpoint=self.endpoint,
#      37         parameters=self.parameters,
#      38         proxy=self.proxy,
#      39         headers=self.headers,
#      40         timeout=self.timeout,
#      41     )
#      42     self.load_response()
#
# File ~/miniconda3/lib/python3.11/site-packages/nba_api/library/http.py:130, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     127         print('loading from file...')
#     129 if not contents:
# --> 130     response = requests.get(url=base_url, params=parameters, headers=request_headers, proxies=proxies, timeout=timeout)
#     131     url = response.url
#     132     status_code = response.status_code
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#     365     tls_in_tls = False
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File ~/miniconda3/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %%
all_series.to_csv("Data/Raw/PLAYOFF_SERIES_BENCH_PTS.csv")
